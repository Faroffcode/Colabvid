# %% [markdown]
# # 🎬 Colabvid
# ### Movie → Instagram Reels → Telegram
#
# Run Cell 1, then Cell 2.

# %%
# CELL 1 — Install all required dependencies
# !apt-get -qq update && apt-get -qq install -y ffmpeg
# !pip install -q gradio requests telethon scenedetect openai-whisper
print('✅ All Colabvid dependencies installed')

# %%
# CELL 2 — Download the latest code and start the Gradio UI
# !rm -rf /content/Colabvid
# !git clone -q https://github.com/Faroffcode/Colabvid.git /content/Colabvid

import sys
sys.path.insert(0, '/content/Colabvid')
import colabvid

app = colabvid.ui()
app.queue().launch(share=True, show_error=True, max_file_size='20gb')
