# %% [markdown]
# # 🎬 Colabvid
# ### Movie → Instagram Reels → Telegram
#
# Run the next cell to install dependencies and launch the Gradio UI.

# %%
# !git clone -q https://github.com/Faroffcode/Colabvid.git /content/Colabvid || (cd /content/Colabvid && git pull -q)
# %run /content/Colabvid/colabvid.py
