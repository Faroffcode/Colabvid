# %% [markdown]
# # 🎬 Colabvid Telegram Bot
# ### Video URL → Reel duration → Clip count → Telegram channel
#
# Run Cell 1, then Cell 2.

# %%
# CELL 1 — Install required dependencies
# !apt-get -qq update && apt-get -qq install -y ffmpeg
# !pip install -q requests telethon
print('✅ Colabvid Telegram bot dependencies installed')

# %%
# CELL 2 — Configure credentials and start the Telegram bot
import os, getpass, sys

os.environ['COLABVID_API_ID'] = getpass.getpass('Telegram API_ID: ')
os.environ['COLABVID_API_HASH'] = getpass.getpass('Telegram API_HASH: ')
os.environ['COLABVID_BOT_TOKEN'] = getpass.getpass('Telegram BOT_TOKEN: ')
os.environ['COLABVID_CHANNEL_ID'] = input('Telegram CHANNEL_ID: ').strip()

# !rm -rf /content/Colabvid
# !git clone -q https://github.com/Faroffcode/Colabvid.git /content/Colabvid

sys.path.insert(0, '/content/Colabvid')
import colabvid
      
await colabvid.start_bot()
